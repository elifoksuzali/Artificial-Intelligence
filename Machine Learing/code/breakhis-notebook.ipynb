# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/README.txt
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/count_files.sh
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/process_db_stat.py
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/fibroadenoma.stat.txt
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/phyllodes_tumor.stat.txt
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/tubular_adenoma.stat.txt
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/adenosis.stat.txt
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/README_B.txt
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/200X/SOB_B_A-14-29960CD-200-012.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/200X/SOB_B_A-14-29960CD-200-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/200X/SOB_B_A-14-29960CD-200-006.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/200X/SOB_B_A-14-29960CD-200-011.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/200X/SOB_B_A-14-29960CD-200-004.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/200X/SOB_B_A-14-29960CD-200-005.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/200X/SOB_B_A-14-29960CD-200-001.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/200X/SOB_B_A-14-29960CD-200-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/200X/SOB_B_A-14-29960CD-200-008.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/200X/SOB_B_A-14-29960CD-200-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/200X/SOB_B_A-14-29960CD-200-015.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/200X/SOB_B_A-14-29960CD-200-003.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/200X/SOB_B_A-14-29960CD-200-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/200X/SOB_B_A-14-29960CD-200-010.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/200X/SOB_B_A-14-29960CD-200-014.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/200X/SOB_B_A-14-29960CD-200-016.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-004.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-003.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-016.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-005.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-014.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-017.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-010.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-008.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-015.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-011.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-012.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-006.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/400X/SOB_B_A-14-29960CD-400-001.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/40X/SOB_B_A-14-29960CD-40-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/40X/SOB_B_A-14-29960CD-40-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/40X/SOB_B_A-14-29960CD-40-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/40X/SOB_B_A-14-29960CD-40-010.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/40X/SOB_B_A-14-29960CD-40-004.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/40X/SOB_B_A-14-29960CD-40-003.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/40X/SOB_B_A-14-29960CD-40-001.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/40X/SOB_B_A-14-29960CD-40-011.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/40X/SOB_B_A-14-29960CD-40-015.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/40X/SOB_B_A-14-29960CD-40-012.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/40X/SOB_B_A-14-29960CD-40-006.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/40X/SOB_B_A-14-29960CD-40-014.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/40X/SOB_B_A-14-29960CD-40-008.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/40X/SOB_B_A-14-29960CD-40-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/40X/SOB_B_A-14-29960CD-40-005.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/100X/SOB_B_A-14-29960CD-100-008.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/100X/SOB_B_A-14-29960CD-100-010.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/100X/SOB_B_A-14-29960CD-100-012.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/100X/SOB_B_A-14-29960CD-100-004.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/100X/SOB_B_A-14-29960CD-100-006.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/100X/SOB_B_A-14-29960CD-100-011.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/100X/SOB_B_A-14-29960CD-100-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/100X/SOB_B_A-14-29960CD-100-001.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/100X/SOB_B_A-14-29960CD-100-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/100X/SOB_B_A-14-29960CD-100-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/100X/SOB_B_A-14-29960CD-100-005.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/100X/SOB_B_A-14-29960CD-100-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-29960CD/100X/SOB_B_A-14-29960CD-100-003.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-018.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-011.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-027.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-012.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-020.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-029.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-004.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-025.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-008.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-030.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-015.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-019.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-021.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-023.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-022.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-026.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-014.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-001.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-031.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-028.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-005.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-024.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-003.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-017.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-016.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-006.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-010.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/200X/SOB_B_A-14-22549CD-200-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-023.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-029.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-016.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-015.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-024.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-026.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-003.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-022.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-010.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-004.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-028.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-011.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-017.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-025.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-027.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-019.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-018.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-014.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-008.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-005.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-012.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-001.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-021.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-020.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-006.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-030.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/400X/SOB_B_A-14-22549CD-400-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-016.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-018.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-020.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-025.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-015.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-027.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-026.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-008.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-028.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-021.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-001.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-034.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-029.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-005.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-004.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-014.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-032.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-012.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-035.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-030.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-024.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-011.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-019.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-003.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-033.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-010.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-022.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-023.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-006.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-017.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/40X/SOB_B_A-14-22549CD-40-031.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-003.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-026.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-012.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-017.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-011.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-022.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-005.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-029.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-015.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-001.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-010.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-018.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-030.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-032.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-020.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-006.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-021.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-014.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-027.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-028.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-019.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-004.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-024.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-036.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-025.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-023.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-031.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-034.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-016.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-033.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-008.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549CD/100X/SOB_B_A-14-22549CD-100-035.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-015.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-019.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-029.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-008.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-004.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-032.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-024.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-025.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-017.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-005.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-001.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-018.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-021.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-028.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-027.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-020.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-026.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-006.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-010.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-011.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-016.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-031.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-022.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-030.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-012.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-014.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-023.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/200X/SOB_B_A-14-22549G-200-003.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-018.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-008.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-028.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-012.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-010.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-006.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-023.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-017.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-027.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-024.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-014.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-019.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-026.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-004.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-001.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-003.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-005.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-015.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-016.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-029.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-021.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-022.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-025.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-020.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/400X/SOB_B_A-14-22549G-400-011.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-014.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-025.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-011.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-005.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-016.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-018.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-010.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-021.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-034.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-001.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-031.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-026.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-027.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-033.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-017.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-020.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-012.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-008.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-006.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-032.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-022.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-004.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-003.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-030.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-023.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-029.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-015.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-024.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-028.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-035.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/40X/SOB_B_A-14-22549G-40-019.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-001.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-020.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-004.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-006.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-015.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-022.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-014.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-003.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-034.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-025.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-016.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-010.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-030.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-008.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-029.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-024.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-018.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-017.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-027.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-028.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-011.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-019.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-033.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-012.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-031.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-026.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-021.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-023.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-032.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549G/100X/SOB_B_A-14-22549G-100-005.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-029.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-010.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-003.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-021.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-005.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-012.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-016.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-031.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-006.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-017.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-025.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-027.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-014.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-022.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-020.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-001.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-023.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-004.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-032.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-008.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-011.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-024.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-028.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-018.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-019.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-026.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-015.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-030.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/200X/SOB_B_A-14-22549AB-200-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/SOB_B_A_14-22549AB/400X/SOB_B_A-14-22549AB-400-019.png
# ...
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/200X/SOB_M_PC-14-15704-200-033.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/200X/SOB_M_PC-14-15704-200-024.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/200X/SOB_M_PC-14-15704-200-015.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/200X/SOB_M_PC-14-15704-200-025.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/200X/SOB_M_PC-14-15704-200-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/200X/SOB_M_PC-14-15704-200-019.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/200X/SOB_M_PC-14-15704-200-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/200X/SOB_M_PC-14-15704-200-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/200X/SOB_M_PC-14-15704-200-022.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/200X/SOB_M_PC-14-15704-200-018.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/200X/SOB_M_PC-14-15704-200-028.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/200X/SOB_M_PC-14-15704-200-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/200X/SOB_M_PC-14-15704-200-023.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/200X/SOB_M_PC-14-15704-200-014.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/200X/SOB_M_PC-14-15704-200-031.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/200X/SOB_M_PC-14-15704-200-017.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-029.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-003.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-021.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-031.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-018.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-028.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-019.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-033.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-034.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-030.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-017.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-024.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-015.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-032.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-004.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-011.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-012.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-026.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-035.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-023.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-006.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-001.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-008.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-027.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-016.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-010.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-020.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-022.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-014.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-025.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/400X/SOB_M_PC-14-15704-400-005.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-008.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-020.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-028.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-025.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-001.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-026.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-015.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-010.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-003.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-029.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-024.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-004.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-016.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-006.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-019.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-018.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-014.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-012.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-011.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-022.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-023.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-021.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-005.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-017.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-027.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-030.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/40X/SOB_M_PC-14-15704-40-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-008.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-016.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-004.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-015.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-011.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-003.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-010.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-006.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-026.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-027.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-025.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-020.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-018.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-028.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-013.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-023.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-009.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-007.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-017.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-012.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-002.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-014.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-024.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-001.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-019.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-022.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-029.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-005.png
# /kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast/malignant/SOB/papillary_carcinoma/SOB_M_PC_14-15704/100X/SOB_M_PC-14-15704-100-021.png

# %% [markdown]
# # Build dataframe of images

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Import necessary libraries for file operations and data processing
import os
import re  # Regular expressions for string parsing
import random  # For random number generation and shuffling
from pathlib import Path  # Object-oriented file system paths
from glob import glob  # File pattern matching
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  # Plotting and visualization
from sklearn.metrics import classification_report, confusion_matrix  # Model evaluation metrics
import itertools  # Efficient looping utilities
import tensorflow as tf  # Deep learning framework
from tensorflow.keras import layers, models, optimizers, callbacks  # Keras components for building/training models
from tensorflow.keras.applications import MobileNetV2  # Pre-trained CNN architecture
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input as mobilenet_preprocess  # Image preprocessing for MobileNet

# Set random seeds for reproducibility across all libraries
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Define the base directory containing the BreakHis dataset
base_input = Path('/kaggle/input/breakhis/BreaKHis_v1/histology_slides/breast')
# Recursively find all PNG images and store their paths as strings
image_paths = sorted([str(p) for p in base_input.rglob('*.png')])

len(image_paths)  # Count total number of images found

def parse_breakhis_path(p: str):
    """
    Parse BreakHis dataset file paths to extract metadata:
    - Label (benign/malignant)
    - Magnification level
    - Patient ID
    
    Args:
        p (str): File path to parse
        
    Returns:
        tuple: (label, magnification, patient_id)
    """
    # Extract filename from full path
    fname = os.path.basename(p)
    # Split filename by underscores to parse structure
    parts = fname.split('_')
    # Second part contains 'B' for benign or 'M' for malignant
    label_token = parts[1] if len(parts) > 1 else ''
    # Convert to full label name
    label = 'benign' if label_token.upper().startswith('B') else 'malignant'
    # Get magnification from parent directory name (e.g., '200X', '40X')
    mag = Path(p).parents[0].name
    # Extract patient ID from filename using string splitting
    try:
        third = parts[2]
        # Remove magnification and slice numbers to get patient ID
        patient = third.rsplit('-', 2)[0]  # 'A-14-29960CD'
    except Exception:
        # Fallback: use regex to find patient pattern if splitting fails
        m = re.search(r'([A-Za-z]-\d+-\w+)', fname)
        patient = m.group(1) if m else fname
    return label, mag, patient

# Create dataframe to store image metadata
rows = []
for p in image_paths:
    label, mag, patient = parse_breakhis_path(p)
    rows.append({'filepath': p, 'label': label, 'mag': mag, 'patient_id': patient})
df = pd.DataFrame(rows)
# Clean and standardize magnification values
df['mag'] = df['mag'].str.upper().str.replace(' ', '')
# Filter to only include 40X and 200X magnifications
df = df[df['mag'].isin(['40X', '200X'])].reset_index(drop=True)
print("Total images (40x and 200x):", len(df))
df.sample(5)  # Display 5 random samples from the dataframe

def patient_stratified_split(df, train_frac=0.7, val_frac=0.1, test_frac=0.2, seed=SEED):
    """
    Split dataset by patient ID to ensure no data leakage between splits.
    This prevents the same patient's images from appearing in multiple splits.
    
    Args:
        df: DataFrame containing image metadata
        train_frac: Proportion of patients for training
        val_frac: Proportion of patients for validation  
        test_frac: Proportion of patients for testing
        seed: Random seed for reproducibility
        
    Returns:
        dict: Nested dictionary with splits for each magnification level
    """
    # Validate that fractions sum to 1.0
    assert abs(train_frac + val_frac + test_frac - 1.0) < 1e-6
    splits = {}
    # Process each magnification level separately
    for mag in df['mag'].unique():
        sub = df[df['mag']==mag].copy()
        patients = sub['patient_id'].unique().tolist()
        # Shuffle patients for random splitting
        random.Random(seed).shuffle(patients)
        n = len(patients)
        # Calculate number of patients for each split
        n_train = int(round(train_frac * n))
        n_val = int(round(val_frac * n))
        # Create sets of patient IDs for each split
        train_pat = set(patients[:n_train])
        val_pat = set(patients[n_train:n_train+n_val])
        test_pat = set(patients[n_train+n_val:])
        # Filter dataframe by patient sets for each split
        splits[mag] = {
            'train': sub[sub['patient_id'].isin(train_pat)],
            'val': sub[sub['patient_id'].isin(val_pat)],
            'test': sub[sub['patient_id'].isin(test_pat)]
        }
    return splits

# Create the patient-stratified splits
splits = patient_stratified_split(df, 0.7, 0.1, 0.2)
# Print split statistics for each magnification
for mag in splits:
    print(mag, {k: len(v) for k,v in splits[mag].items()})

# Display detailed split information
for mag in splits:
    print(f"\n=== {mag} ===")
    for split_name, split_df in splits[mag].items():
        n_images = len(split_df)
        n_patients = split_df['patient_id'].nunique()
        print(f"{split_name:>5} | images: {n_images:4d} | patients: {n_patients:3d}")

# Check GPU availability and set environment
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Force CPU usage (comment out to use GPU if available)
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
print("Running on:", "GPU" if tf.config.list_physical_devices('GPU') else "CPU")

# Define constants for model training
IMG_SIZE = (224, 224)  # Standard input size for MobileNet and custom CNN
BATCH_SIZE = 32  # Number of samples per training batch
AUTOTUNE = tf.data.AUTOTUNE  # Let TensorFlow optimize data loading
CLASS_NAMES = ['benign', 'malignant']  # Classification categories
# Create mapping from class names to numerical indices
label_to_idx = {c:i for i,c in enumerate(CLASS_NAMES)}

def path_to_tensor(path, img_size=IMG_SIZE, preprocess=None):
    """
    Load and preprocess an image from file path to tensor format.
    
    Args:
        path: Image file path
        img_size: Target image dimensions
        preprocess: Optional preprocessing function
        
    Returns:
        tf.Tensor: Preprocessed image tensor
    """
    # Read image file
    img = tf.io.read_file(path)
    # Decode PNG image to tensor
    img = tf.image.decode_png(img, channels=3)
    # Resize to target dimensions
    img = tf.image.resize(img, img_size)
    # Convert to float32
    img = tf.cast(img, tf.float32)
    # Apply model-specific preprocessing or normalize to [0,1]
    if preprocess is not None:
        img = preprocess(img)
    else:
        img = img / 255.0
    return img

# Define data augmentation pipeline using Keras layers
data_augment = tf.keras.Sequential([
    layers.RandomFlip('horizontal_and_vertical'),  # Random flips
    layers.RandomRotation(0.1),  # Random rotation ±10%
    layers.RandomTranslation(0.05, 0.05),  # Random translation ±5%
    layers.RandomZoom(0.05, 0.05),  # Random zoom ±5%
])

def df_to_tf_dataset(df, preprocess=None, shuffle=False, repeat=False):
    """
    Convert DataFrame to TensorFlow Dataset for efficient training.
    
    Args:
        df: DataFrame with filepaths and labels
        preprocess: Image preprocessing function
        shuffle: Whether to shuffle the dataset
        repeat: Whether to repeat dataset indefinitely
        
    Returns:
        tf.data.Dataset: Configured TensorFlow dataset
    """
    paths = df['filepath'].values
    labels = [label_to_idx[l] for l in df['label'].values]
    # Create dataset from file paths and labels
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    # Shuffle if requested
    if shuffle:
        ds = ds.shuffle(buffer_size=len(paths), seed=SEED)
    
    def _load(path, label):
        """Internal function to load and preprocess single image"""
        img = path_to_tensor(path, IMG_SIZE, preprocess)
        return img, label
    
    # Map loading function across dataset
    ds = ds.map(_load, num_parallel_calls=AUTOTUNE)
    # Repeat indefinitely if needed (for large epoch counts)
    if repeat:
        ds = ds.repeat()
    # Batch and prefetch for performance
    ds = ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return ds

# =============================================================================
# ENHANCED MODEL ARCHITECTURES
# =============================================================================

def build_custom_cnn(input_shape=(*IMG_SIZE,3), num_classes=2):
    """Original custom CNN architecture"""
    inputs = layers.Input(shape=input_shape)
    x = data_augment(inputs)
    x = layers.Conv2D(32, 3, activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool2D()(x)
    x = layers.Dropout(0.25)(x)
    
    x = layers.Conv2D(64, 3, activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool2D()(x)
    x = layers.Dropout(0.25)(x)
    
    x = layers.Conv2D(128, 3, activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool2D()(x)
    x = layers.Dropout(0.25)(x)
    
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs, name='custom_cnn')
    return model

def build_enhanced_cnn(input_shape=(*IMG_SIZE,3), num_classes=2):
    """Enhanced CNN with better architecture to handle imbalance"""
    inputs = layers.Input(shape=input_shape)
    
    # Stronger augmentation
    x = layers.RandomFlip('horizontal_and_vertical')(inputs)
    x = layers.RandomRotation(0.2)(x)
    x = layers.RandomZoom(0.15)(x)
    x = layers.RandomContrast(0.1)(x)
    
    # Block 1 - More filters and better regularization
    x = layers.Conv2D(64, 3, activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool2D()(x)
    x = layers.Dropout(0.3)(x)
    
    # Block 2
    x = layers.Conv2D(128, 3, activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool2D()(x)
    x = layers.Dropout(0.4)(x)
    
    # Block 3 - Depthwise separable convolution for efficiency
    x = layers.SeparableConv2D(256, 3, activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    
    # Classifier head with regularization
    x = layers.Dense(128, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs, name='enhanced_cnn')
    return model

def build_mobilenet_v2(input_shape=(*IMG_SIZE,3), num_classes=2, trainable_base=False):
    """
    Build MobileNetV2 model with transfer learning.
    
    Args:
        input_shape: Shape of input images
        num_classes: Number of output classes
        trainable_base: Whether to fine-tune base MobileNet weights
        
    Returns:
        tf.keras.Model: MobileNetV2 model with custom classifier
    """
    inputs = layers.Input(shape=input_shape)
    # Load pre-trained MobileNetV2 without top classification layers
    base = MobileNetV2(include_top=False, input_shape=input_shape, weights='imagenet', pooling='avg')
    # Freeze or unfreeze base model weights
    base.trainable = trainable_base
    # Pass inputs through base model
    x = base(inputs, training=False)  # training=False for batch norm in inference mode
    # Add custom classifier head
    x = layers.Dense(256, activation='relu')(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs, name='mobilenet_v2_tl')
    return model

# =============================================================================
# ENHANCED TRAINING FUNCTIONS WITH CLASS WEIGHTS
# =============================================================================

def compile_and_train(model, train_ds, val_ds, epochs=20, model_name='model', patience=4, class_weight=None):
    """
    Enhanced training function with class weights support
    """
    # Use lower learning rate for better convergence
    model.compile(
        optimizer=optimizers.Adam(1e-4),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    
    callbacks_list = [
        callbacks.ModelCheckpoint(f'{model_name}.h5', save_best_only=True, monitor='val_loss'),
        callbacks.EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True),
        callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-7)
    ]
    
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
        callbacks=callbacks_list,
        class_weight=class_weight  # Crucial for handling imbalance
    )
    return history

# =============================================================================
# MAIN TRAINING PIPELINE
# =============================================================================

# Process 40X magnification images
mag = '40X'
print(f"\n{'='*50}\nProcessing {mag}\n{'='*50}")
# Get splits for current magnification
train_df = splits[mag]['train'].reset_index(drop=True)
val_df   = splits[mag]['val'].reset_index(drop=True)
test_df  = splits[mag]['test'].reset_index(drop=True)
print("Counts:", len(train_df), len(val_df), len(test_df))

# Calculate class weights to handle imbalance
print("\nCalculating class weights...")
train_labels = train_df['label'].map({'benign': 0, 'malignant': 1})
benign_count = np.sum(train_labels == 0)
malignant_count = np.sum(train_labels == 1)
total = benign_count + malignant_count

# Give more weight to the minority class (benign)
class_weight = {
    0: total / (2 * benign_count),   # Higher weight for benign
    1: total / (2 * malignant_count) # Lower weight for malignant
}
print(f"Class distribution - Benign: {benign_count}, Malignant: {malignant_count}")
print(f"Class weights - Benign: {class_weight[0]:.2f}, Malignant: {class_weight[1]:.2f}")

# Create datasets for custom CNN (no special preprocessing)
train_ds = df_to_tf_dataset(train_df, preprocess=None, shuffle=True, repeat=False)
val_ds   = df_to_tf_dataset(val_df, preprocess=None, shuffle=False)
test_ds  = df_to_tf_dataset(test_df, preprocess=None, shuffle=False)

# Create datasets for MobileNet (with MobileNet-specific preprocessing)
train_ds_mob = df_to_tf_dataset(train_df, preprocess=mobilenet_preprocess, shuffle=True, repeat=False)
val_ds_mob   = df_to_tf_dataset(val_df, preprocess=mobilenet_preprocess, shuffle=False)
test_ds_mob  = df_to_tf_dataset(test_df, preprocess=mobilenet_preprocess, shuffle=False)

# Train Enhanced Custom CNN with class weights
print("\n" + "="*60)
print("TRAINING ENHANCED CUSTOM CNN WITH CLASS WEIGHTS")
print("="*60)
enhanced_cnn = build_enhanced_cnn()
enhanced_history = compile_and_train(
    enhanced_cnn, 
    train_ds, 
    val_ds, 
    epochs=50, 
    model_name=f'enhanced_cnn_{mag.lower()}',
    class_weight=class_weight
)

# Also train original CNN for comparison
print("\n" + "="*60)
print("TRAINING ORIGINAL CUSTOM CNN WITH CLASS WEIGHTS")
print("="*60)
custom_cnn = build_custom_cnn()
custom_history = compile_and_train(
    custom_cnn, 
    train_ds, 
    val_ds, 
    epochs=50, 
    model_name=f'custom_cnn_{mag.lower()}',
    class_weight=class_weight
)

# Build and train MobileNetV2 with transfer learning
print("\n" + "="*60)
print("TRAINING MOBILENET V2 WITH CLASS WEIGHTS")
print("="*60)
mobilenet = build_mobilenet_v2(trainable_base=False)
mobilenet_history = compile_and_train(
    mobilenet, 
    train_ds_mob, 
    val_ds_mob, 
    epochs=15, 
    model_name=f'mobilenet_{mag.lower()}',
    class_weight=class_weight
)

# Fine-tuning: unfreeze some layers for additional training
print("\n" + "="*60)
print("FINE-TUNING MOBILENET V2")
print("="*60)
mobilenet.trainable = True
# Freeze early layers, unfreeze later layers for fine-tuning
for layer in mobilenet.layers[:-20]:
    layer.trainable = False

mobilenet_history_ft = compile_and_train(
    mobilenet, 
    train_ds_mob, 
    val_ds_mob, 
    epochs=10, 
    model_name=f'mobilenet_{mag.lower()}_finetuned', 
    patience=3,
    class_weight=class_weight
)

# =============================================================================
# EVALUATION AND VISUALIZATION
# =============================================================================

def evaluate_and_report(model, df_test, preprocess=None):
    """
    Evaluate model on test set and generate classification report.
    
    Args:
        model: Trained model to evaluate
        df_test: Test dataframe
        preprocess: Preprocessing function if required
        
    Returns:
        tuple: Confusion matrix, true labels, predicted labels
    """
    ds = df_to_tf_dataset(df_test, preprocess=preprocess, shuffle=False)
    # Generate predictions
    preds = model.predict(ds)
    # Convert probabilities to class predictions
    y_pred = np.argmax(preds, axis=1)
    # Get true labels
    y_true = [label_to_idx[l] for l in df_test['label'].values]
    # Print detailed classification report
    print(classification_report(y_true, y_pred, target_names=CLASS_NAMES))
    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    return cm, y_true, y_pred

# Evaluate all models on test set
print("\n" + "="*60)
print("EVALUATION RESULTS")
print("="*60)

print(f"\nEnhanced Custom CNN ({mag}) evaluation:")
cm_enhanced, y_true_enhanced, y_pred_enhanced = evaluate_and_report(enhanced_cnn, test_df)

print(f"\nOriginal Custom CNN ({mag}) evaluation:")
cm_custom, y_true_custom, y_pred_custom = evaluate_and_report(custom_cnn, test_df)

print(f"\nMobileNet ({mag}) evaluation:")
cm_mobilenet, y_true_mob, y_pred_mob = evaluate_and_report(mobilenet, test_df, preprocess=mobilenet_preprocess)

def plot_confusion_matrix(cm, classes, title='Confusion matrix'):
    """
    Plot confusion matrix as a heatmap.
    
    Args:
        cm: Confusion matrix array
        classes: Class names for labeling
        title: Plot title
    """
    plt.figure(figsize=(5,5))
    plt.imshow(cm, interpolation='nearest')
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    fmt = 'd'
    thresh = cm.max() / 2.
    # Add text annotations to each cell
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

# Plot confusion matrices for all models
print("\n" + "="*60)
print("CONFUSION MATRICES")
print("="*60)

plot_confusion_matrix(cm_enhanced, CLASS_NAMES, title=f'Enhanced CNN - {mag}')
plot_confusion_matrix(cm_custom, CLASS_NAMES, title=f'Original CNN - {mag}')
plot_confusion_matrix(cm_mobilenet, CLASS_NAMES, title=f'MobileNetV2 - {mag}')

def plot_training_history(history, model_name='Model'):
    """
    Plot training history showing accuracy and loss curves.
    
    Args:
        history: Training history object from model.fit()
        model_name: Name for plot titles
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    
    # Plot accuracy curves
    ax1.plot(history.history['accuracy'], label='Training Accuracy')
    ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_title(f'{model_name} - Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    ax1.grid(True)
    
    # Plot loss curves
    ax2.plot(history.history['loss'], label='Training Loss')
    ax2.plot(history.history['val_loss'], label='Validation Loss')
    ax2.set_title(f'{model_name} - Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    ax2.grid(True)
    
    plt.tight_layout()
    plt.show()

# Plot training histories for all models
print("\n" + "="*60)
print("TRAINING HISTORIES")
print("="*60)

print(f"Enhanced CNN Training History ({mag}):")
plot_training_history(enhanced_history, f'Enhanced CNN - {mag}')

print(f"Original CNN Training History ({mag}):")
plot_training_history(custom_history, f'Original CNN - {mag}')

print(f"MobileNetV2 Training History ({mag}):")
plot_training_history(mobilenet_history, f'MobileNetV2 - {mag}')

print(f"MobileNetV2 Fine-tuned Training History ({mag}):")
plot_training_history(mobilenet_history_ft, f'MobileNetV2 Fine-tuned - {mag}')

# =============================================================================
# PERFORMANCE SUMMARY
# =============================================================================

print("\n" + "="*60)
print("PERFORMANCE SUMMARY")
print("="*60)

def calculate_metrics(cm, model_name):
    tn, fp, fn, tp = cm.ravel()
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    print(f"\n{model_name}:")
    print(f"  Accuracy:    {accuracy:.3f}")
    print(f"  Precision:   {precision:.3f}")
    print(f"  Recall:      {recall:.3f}")
    print(f"  Specificity: {specificity:.3f}")
    print(f"  F1-Score:    {f1:.3f}")
    print(f"  Confusion Matrix:\n{cm}")

calculate_metrics(cm_enhanced, "Enhanced Custom CNN")
calculate_metrics(cm_custom, "Original Custom CNN")
calculate_metrics(cm_mobilenet, "MobileNetV2")

print("\n" + "="*60)
print("TRAINING COMPLETE!")
print("="*60)

# =============================================================================
# MODEL ARCHITECTURE SUMMARIES
# =============================================================================

print("\n" + "="*80)
print("MODEL ARCHITECTURE SUMMARIES")
print("="*80)

# Enhanced Custom CNN Summary
print("\n" + "="*50)
print("ENHANCED CUSTOM CNN ARCHITECTURE SUMMARY")
print("="*50)
enhanced_cnn_summary = build_enhanced_cnn()
enhanced_cnn_summary.summary()

# Original Custom CNN Summary  
print("\n" + "="*50)
print("ORIGINAL CUSTOM CNN ARCHITECTURE SUMMARY")
print("="*50)
custom_cnn_summary = build_custom_cnn()
custom_cnn_summary.summary()

# MobileNetV2 Summary
print("\n" + "="*50)
print("MOBILENET V2 ARCHITECTURE SUMMARY")
print("="*50)
mobilenet_summary = build_mobilenet_v2(trainable_base=False)
mobilenet_summary.summary()

# MobileNetV2 Fine-tuned Summary
print("\n" + "="*50)
print("MOBILENET V2 FINE-TUNED ARCHITECTURE SUMMARY")
print("="*50)
mobilenet_ft_summary = build_mobilenet_v2(trainable_base=True)
# Freeze early layers for fine-tuning
for layer in mobilenet_ft_summary.layers[:-20]:
    layer.trainable = False
mobilenet_ft_summary.summary()
# Out:
# 2025-10-25 18:17:48.709959: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761416268.943516      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761416269.000993      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Total images (40x and 200x): 4008
# 200X {'train': 1329, 'val': 173, 'test': 511}
# 40X {'train': 1350, 'val': 191, 'test': 454}
#
# === 200X ===
# train | images: 1329 | patients:  57
#   val | images:  173 | patients:   8
#  test | images:  511 | patients:  17
#
# === 40X ===
# train | images: 1350 | patients:  57
#   val | images:  191 | patients:   8
#  test | images:  454 | patients:  17
# Num GPUs Available: 2
# Running on: GPU
#
# ==================================================
# Processing 40X
# ==================================================
# Counts: 1350 191 454
#
# Calculating class weights...
# Class distribution - Benign: 453, Malignant: 897
# Class weights - Benign: 1.49, Malignant: 0.75
# I0000 00:00:1761416282.619184      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1761416282.619826      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# ============================================================
# TRAINING ENHANCED CUSTOM CNN WITH CLASS WEIGHTS
# ============================================================
# Epoch 1/50
# E0000 00:00:1761416290.643731      19 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/enhanced_cnn_1/dropout_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# I0000 00:00:1761416293.456133      61 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 25s 321ms/step - accuracy: 0.6398 - loss: 0.8731 - val_accuracy: 1.0000 - val_loss: 0.6087 - learning_rate: 1.0000e-04
# Epoch 2/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 290ms/step - accuracy: 0.7328 - loss: 0.6597 - val_accuracy: 1.0000 - val_loss: 0.5247 - learning_rate: 1.0000e-04
# Epoch 3/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 294ms/step - accuracy: 0.7410 - loss: 0.6379 - val_accuracy: 1.0000 - val_loss: 0.4276 - learning_rate: 1.0000e-04
# Epoch 4/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 298ms/step - accuracy: 0.7530 - loss: 0.5812 - val_accuracy: 1.0000 - val_loss: 0.3579 - learning_rate: 1.0000e-04
# Epoch 5/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 14s 315ms/step - accuracy: 0.7596 - loss: 0.5549 - val_accuracy: 1.0000 - val_loss: 0.2760 - learning_rate: 1.0000e-04
# Epoch 6/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 307ms/step - accuracy: 0.7549 - loss: 0.5441 - val_accuracy: 1.0000 - val_loss: 0.2410 - learning_rate: 1.0000e-04
# Epoch 7/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 14s 317ms/step - accuracy: 0.7715 - loss: 0.5866 - val_accuracy: 1.0000 - val_loss: 0.1957 - learning_rate: 1.0000e-04
# Epoch 8/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 14s 316ms/step - accuracy: 0.7964 - loss: 0.4622 - val_accuracy: 1.0000 - val_loss: 0.1671 - learning_rate: 1.0000e-04
# Epoch 9/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 305ms/step - accuracy: 0.8026 - loss: 0.4607 - val_accuracy: 1.0000 - val_loss: 0.1870 - learning_rate: 1.0000e-04
# Epoch 10/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 303ms/step - accuracy: 0.7939 - loss: 0.4810 - val_accuracy: 0.9895 - val_loss: 0.2056 - learning_rate: 1.0000e-04
# Epoch 11/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 303ms/step - accuracy: 0.8005 - loss: 0.4806 - val_accuracy: 0.9843 - val_loss: 0.1683 - learning_rate: 5.0000e-05
# Epoch 12/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 304ms/step - accuracy: 0.7940 - loss: 0.4848 - val_accuracy: 0.9634 - val_loss: 0.2034 - learning_rate: 5.0000e-05
#
# ============================================================
# TRAINING ORIGINAL CUSTOM CNN WITH CLASS WEIGHTS
# ============================================================
# Epoch 1/50
# E0000 00:00:1761416460.016333      19 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/custom_cnn_1/dropout_4_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 14s 186ms/step - accuracy: 0.6338 - loss: 0.6730 - val_accuracy: 1.0000 - val_loss: 0.5449 - learning_rate: 1.0000e-04
# Epoch 2/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 0.7882 - loss: 0.4993 - val_accuracy: 1.0000 - val_loss: 0.4105 - learning_rate: 1.0000e-04
# Epoch 3/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 0.7665 - loss: 0.5430 - val_accuracy: 1.0000 - val_loss: 0.3241 - learning_rate: 1.0000e-04
# Epoch 4/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 0.8071 - loss: 0.4517 - val_accuracy: 1.0000 - val_loss: 0.2486 - learning_rate: 1.0000e-04
# Epoch 5/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 0.8084 - loss: 0.4355 - val_accuracy: 1.0000 - val_loss: 0.1938 - learning_rate: 1.0000e-04
# Epoch 6/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 0.8063 - loss: 0.4458 - val_accuracy: 1.0000 - val_loss: 0.1609 - learning_rate: 1.0000e-04
# Epoch 7/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 0.8394 - loss: 0.3721 - val_accuracy: 1.0000 - val_loss: 0.1439 - learning_rate: 1.0000e-04
# Epoch 8/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 0.8359 - loss: 0.3768 - val_accuracy: 0.9895 - val_loss: 0.1859 - learning_rate: 1.0000e-04
# Epoch 9/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 0.8569 - loss: 0.3635 - val_accuracy: 0.9005 - val_loss: 0.2523 - learning_rate: 1.0000e-04
# Epoch 10/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 0.8320 - loss: 0.3765 - val_accuracy: 0.8220 - val_loss: 0.3671 - learning_rate: 5.0000e-05
# Epoch 11/50
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 0.8466 - loss: 0.3794 - val_accuracy: 0.7853 - val_loss: 0.5368 - learning_rate: 5.0000e-05
#
# ============================================================
# TRAINING MOBILENET V2 WITH CLASS WEIGHTS
# ============================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/15
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761416547.799345      61 service.cc:148] XLA service 0x7fe3d3cad4f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761416547.800338      61 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761416547.800350      61 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#  6/43 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.6234 - loss: 0.7570
# I0000 00:00:1761416552.494007      61 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 25s 343ms/step - accuracy: 0.6375 - loss: 0.6679 - val_accuracy: 0.6911 - val_loss: 0.6123 - learning_rate: 1.0000e-04
# Epoch 2/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 130ms/step - accuracy: 0.7780 - loss: 0.4546 - val_accuracy: 0.7749 - val_loss: 0.4891 - learning_rate: 1.0000e-04
# Epoch 3/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 130ms/step - accuracy: 0.8629 - loss: 0.3588 - val_accuracy: 0.7906 - val_loss: 0.4641 - learning_rate: 1.0000e-04
# Epoch 4/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.8849 - loss: 0.3023 - val_accuracy: 0.7487 - val_loss: 0.5400 - learning_rate: 1.0000e-04
# Epoch 5/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9165 - loss: 0.2503 - val_accuracy: 0.7173 - val_loss: 0.5712 - learning_rate: 1.0000e-04
# Epoch 6/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - accuracy: 0.9226 - loss: 0.2302 - val_accuracy: 0.7906 - val_loss: 0.4592 - learning_rate: 5.0000e-05
# Epoch 7/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9363 - loss: 0.2127 - val_accuracy: 0.7173 - val_loss: 0.5874 - learning_rate: 5.0000e-05
# Epoch 8/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - accuracy: 0.9309 - loss: 0.1916 - val_accuracy: 0.8168 - val_loss: 0.4218 - learning_rate: 5.0000e-05
# Epoch 9/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.9517 - loss: 0.1834 - val_accuracy: 0.8168 - val_loss: 0.4016 - learning_rate: 5.0000e-05
# Epoch 10/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.9535 - loss: 0.1738 - val_accuracy: 0.8010 - val_loss: 0.4455 - learning_rate: 5.0000e-05
# Epoch 11/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 132ms/step - accuracy: 0.9594 - loss: 0.1667 - val_accuracy: 0.8325 - val_loss: 0.3627 - learning_rate: 5.0000e-05
# Epoch 12/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - accuracy: 0.9675 - loss: 0.1524 - val_accuracy: 0.8325 - val_loss: 0.3571 - learning_rate: 5.0000e-05
# Epoch 13/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - accuracy: 0.9761 - loss: 0.1364 - val_accuracy: 0.8482 - val_loss: 0.3179 - learning_rate: 5.0000e-05
# Epoch 14/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9772 - loss: 0.1386 - val_accuracy: 0.8220 - val_loss: 0.3605 - learning_rate: 5.0000e-05
# Epoch 15/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.9719 - loss: 0.1344 - val_accuracy: 0.8429 - val_loss: 0.3337 - learning_rate: 5.0000e-05
#
# ============================================================
# FINE-TUNING MOBILENET V2
# ============================================================
# Epoch 1/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 19s 253ms/step - accuracy: 0.9716 - loss: 0.1397 - val_accuracy: 0.8377 - val_loss: 0.3406 - learning_rate: 1.0000e-04
# Epoch 2/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9822 - loss: 0.1190 - val_accuracy: 0.8272 - val_loss: 0.3542 - learning_rate: 1.0000e-04
# Epoch 3/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9794 - loss: 0.1090 - val_accuracy: 0.7801 - val_loss: 0.4949 - learning_rate: 1.0000e-04
# Epoch 4/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - accuracy: 0.9905 - loss: 0.0921 - val_accuracy: 0.8482 - val_loss: 0.3206 - learning_rate: 5.0000e-05
# Epoch 5/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - accuracy: 0.9848 - loss: 0.0839 - val_accuracy: 0.8796 - val_loss: 0.2877 - learning_rate: 5.0000e-05
# Epoch 6/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9931 - loss: 0.0771 - val_accuracy: 0.8010 - val_loss: 0.4143 - learning_rate: 5.0000e-05
# Epoch 7/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 130ms/step - accuracy: 0.9861 - loss: 0.0826 - val_accuracy: 0.8848 - val_loss: 0.2726 - learning_rate: 5.0000e-05
# Epoch 8/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9963 - loss: 0.0709 - val_accuracy: 0.8429 - val_loss: 0.3311 - learning_rate: 5.0000e-05
# Epoch 9/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.9973 - loss: 0.0669 - val_accuracy: 0.8796 - val_loss: 0.3022 - learning_rate: 5.0000e-05
# Epoch 10/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9964 - loss: 0.0597 - val_accuracy: 0.8377 - val_loss: 0.3306 - learning_rate: 2.5000e-05
#
# ============================================================
# EVALUATION RESULTS
# ============================================================
#
# Enhanced Custom CNN (40X) evaluation:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step
#               precision    recall  f1-score   support
#
#       benign       0.00      0.00      0.00       172
#    malignant       0.62      1.00      0.77       282
#
#     accuracy                           0.62       454
#    macro avg       0.31      0.50      0.38       454
# weighted avg       0.39      0.62      0.48       454
#
#
# Original Custom CNN (40X) evaluation:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
#               precision    recall  f1-score   support
#
#       benign       1.00      0.01      0.01       172
#    malignant       0.62      1.00      0.77       282
#
#     accuracy                           0.62       454
#    macro avg       0.81      0.50      0.39       454
# weighted avg       0.77      0.62      0.48       454
#
#
# MobileNet (40X) evaluation:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 318ms/step
#               precision    recall  f1-score   support
#
#       benign       0.75      0.67      0.71       172
#    malignant       0.81      0.86      0.84       282
#
#     accuracy                           0.79       454
#    macro avg       0.78      0.77      0.77       454
# weighted avg       0.79      0.79      0.79       454
#
#
# ============================================================
# CONFUSION MATRICES
# ============================================================
# ============================================================
# TRAINING HISTORIES
# ============================================================
# Enhanced CNN Training History (40X):
# Original CNN Training History (40X):
# MobileNetV2 Training History (40X):
# MobileNetV2 Fine-tuned Training History (40X):
# ============================================================
# PERFORMANCE SUMMARY
# ============================================================
#
# Enhanced Custom CNN:
#   Accuracy:    0.621
#   Precision:   0.621
#   Recall:      1.000
#   Specificity: 0.000
#   F1-Score:    0.766
#   Confusion Matrix:
# [[  0 172]
#  [  0 282]]
#
# Original Custom CNN:
#   Accuracy:    0.623
#   Precision:   0.623
#   Recall:      1.000
#   Specificity: 0.006
#   F1-Score:    0.767
#   Confusion Matrix:
# [[  1 171]
#  [  0 282]]
#
# MobileNetV2:
#   Accuracy:    0.789
#   Precision:   0.810
#   Recall:      0.862
#   Specificity: 0.669
#   F1-Score:    0.835
#   Confusion Matrix:
# [[115  57]
#  [ 39 243]]
#
# ============================================================
# TRAINING COMPLETE!
# ============================================================
#
# ================================================================================
# MODEL ARCHITECTURE SUMMARIES
# ================================================================================
#
# ==================================================
# ENHANCED CUSTOM CNN ARCHITECTURE SUMMARY
# ==================================================
# Model: "enhanced_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_flip_2 (RandomFlip)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation_2               │ (None, 224, 224, 3)    │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom_2 (RandomZoom)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_contrast_1               │ (None, 224, 224, 3)    │             0 │
# │ (RandomContrast)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 224, 224, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 112, 112, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_1              │ (None, 56, 56, 256)    │        34,176 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 56, 56, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 145,282 (567.51 KB)
#  Trainable params: 144,130 (563.01 KB)
#  Non-trainable params: 1,152 (4.50 KB)
# ==================================================
# ORIGINAL CUSTOM CNN ARCHITECTURE SUMMARY
# ==================================================
# Model: "custom_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_4      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 2)              │           514 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 127,682 (498.76 KB)
#  Trainable params: 127,234 (497.01 KB)
#  Non-trainable params: 448 (1.75 KB)
# ==================================================
# MOBILENET V2 ARCHITECTURE SUMMARY
# ==================================================
# Model: "mobilenet_v2_tl"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 2)              │           514 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,586,434 (9.87 MB)
#  Trainable params: 328,450 (1.25 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# ==================================================
# MOBILENET V2 FINE-TUNED ARCHITECTURE SUMMARY
# ==================================================
# Model: "mobilenet_v2_tl"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_9 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 2)              │           514 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,586,434 (9.87 MB)
#  Trainable params: 2,552,322 (9.74 MB)
#  Non-trainable params: 34,112 (133.25 KB)

# %%
print(f"Class distribution - Benign: {benign_count}, Malignant: {malignant_count}")
print(f"Class weights - Benign: {class_weight[0]:.2f}, Malignant: {class_weight[1]:.2f}")
# Out:
# Class distribution - Benign: 453, Malignant: 897
# Class weights - Benign: 1.49, Malignant: 0.75
