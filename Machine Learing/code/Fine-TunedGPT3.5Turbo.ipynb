# %%
import google.generativeai as genai

# Google Generative AI modelini ayarlama
genai.configure(api_key="AIzaSyCHItAly9xAzZQlrybfa8bHXyoGvh_UPRY")

# Model oluşturma
generation_config = {
    "temperature": 0.9,
    "top_p": 1,
    "top_k": 1,
    "max_output_tokens": 2048,
}

safety_settings = [
    {
        "category": "HARM_CATEGORY_HARASSMENT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE"
    },
    {
        "category": "HARM_CATEGORY_HATE_SPEECH",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE"
    },
    {
        "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE"
    },
    {
        "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE"
    }
]

model = genai.GenerativeModel(model_name="gemini-pro",
                                generation_config=generation_config,
                                safety_settings=safety_settings)




# Prompt oluşturma
prompt_parts = [
    f"""Bir tur içerik üreticisi olarak hareket etmeni istiyorum. Sana tur içeriği hakkındaki bazı bilgileri yazacağım ve sen de bu bilgilerle zengin
       bir tur planı oluşturacaksın.Ben sana tur içeriği hakkındaki bazı bilgileri yazacağım ve sen de bu bilgiler ile bir tur planı oluşturacaksın ve
       gezilecek olan yerin tarihi,önemli noktalarını betimleyerek anlatacaksın aynı zamanda gün gün yapılacak etkinlikleri belirtecek bu tur içeriğine özel
       bir tur başlığı ile beraber tur içerik oluşturacaksın. Bazı durumlarda sana ziyaret edilecek yerleri,tur dahil hizmetleri,uçuş bilgileri,restoran
       bilgileri,tura dahil olan hizmetleri,tura dahil olmayana hizmetleri,konaklamaya, tur başlangıcı için toplanma yerlerini,turun son gününü belirterek
       içeriği oluşturacak son gün aktivitelerinden sonra dönüşe geçiyor veya başka turlarda görüşmek dileğiyle gibi temenni cümlelerine yer vereceksin. Ayrıca bir içerik değil birden farklı
       türde içerik oluşturup önereceksiniz tur içeriğinde temel unsurlar verildiğinde bunları betimleyerek içeriği oluştur. Gezilecek mekanların
       bilgisi,şehrin tarihi,doğası,turistlik açıdan önemi ve önemli noktalarını betimleyerek içeriği zengin bir tur metni üretmeni istiyorum.
       Planı oluştururken aşağıdaki hususları dikkate almanı istiyorum: ve sadece 2 günlük tur yazacaksın daha fazlasını yazarsan şirketim batar sakın yazma
       Tur Başlığı ve Genel Bakış: Tur için ilgi çekici bir başlık oluştur. Turun süresini ve tur temalarını belirt. Tur boyunca ziyaret edilecek şehir veya bölgeleri ve
       başlangıç güzergahını da ekle.Gezilecek Yerler ve Tarihi Özellikler: Her gün için ziyaret edilecek yerlerin tarihini, önemli noktalarını ve benzersiz özelliklerini betimle. Gezilecek yerleri
       detaylı şekilde tanımla ve neden ziyaret edilmeleri gerektiğini açıkla.Gün Gün Etkinlikler ve Aktiviteler: Turun her günü için yapılacak"""]


response = model.generate_content(prompt_parts)
print(response.text)

# %%
import google.generativeai as genai
import gradio as gr

# Google Generative AI modelini ayarlama
genai.configure(api_key="AIzaSyCHItAly9xAzZQlrybfa8bHXyoGvh_UPRY")

# Model oluşturma
generation_config = {
 "temperature": 0.9,
 "top_p": 1,
 "top_k": 1,
 "max_output_tokens": 2048,
}

safety_settings = [
 {
 "category": "HARM_CATEGORY_HARASSMENT",
 "threshold": "BLOCK_MEDIUM_AND_ABOVE"
 },
{
 "category": "HARM_CATEGORY_HATE_SPEECH",
 "threshold": "BLOCK_MEDIUM_AND_ABOVE"
},
{
 "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
 "threshold": "BLOCK_MEDIUM_AND_ABOVE"
},
{
 "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
 "threshold": "BLOCK_MEDIUM_AND_ABOVE"
}
]

model = genai.GenerativeModel(model_name="gemini-pro",
 generation_config=generation_config,
 safety_settings=safety_settings)





def generate_tour_content(gezilecek_yerler_str, kac_gunluk, baslangic_yeri, bitis_yeri):
 # Kullanıcı tarafından girilen bilgileri listeye dönüştürme
    gezilecek_yerler = gezilecek_yerler_str.split(",")

    # Prompt oluşturma
    prompt_parts = [
    f"""Bir tur içerik üreticisi olarak hareket etmeni istiyorum. Sana tur içeriği hakkındaki bazı bilgileri yazacağım ve sen de bu bilgilerle zengin
       bir tur planı oluşturacaksın.Ben sana tur içeriği hakkındaki bazı bilgileri yazacağım ve sen de bu bilgiler ile bir tur planı oluşturacaksın ve
               gezilecek olan yerin tarihi,önemli noktalarını betimleyerek anlatacaksın aynı zamanda gün gün yapılacak etkinlikleri belirtecek bu tur içeriğine özel
               bir tur başlığı ile beraber tur içerik oluşturacaksın. Bazı durumlarda sana ziyaret edilecek yerleri,tur dahil hizmetleri,uçuş bilgileri,restoran
               bilgileri,tura dahil olan hizmetleri,tura dahil olmayana hizmetleri,konaklamaya, tur başlangıcı için toplanma yerlerini"""]

    # Prompt'u birleştirme
    prompt = "\n".join(prompt_parts)

    # Modelin çalıştırılması
    response = model.generate_content(prompt)

    # Oluşturulan tur içeriğini geri döndürme
    return response.content.decode("utf-8")

# %%
import google.generativeai as genai

# Google Generative AI modelini ayarlama
genai.configure(api_key="AIzaSyCHItAly9xAzZQlrybfa8bHXyoGvh_UPRY")

# Model oluşturma
generation_config = {
    "temperature": 0.9,
    "top_p": 1,
    "top_k": 1,
    "max_output_tokens": 2048,
}

safety_settings = [
    {
        "category": "HARM_CATEGORY_HARASSMENT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE"
    },
    {
        "category": "HARM_CATEGORY_HATE_SPEECH",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE"
    },
    {
        "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE"
    },
    {
        "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
        "threshold": "BLOCK_MEDIUM_AND_ABOVE"
    }
]

model = genai.GenerativeModel(model_name="gemini-pro",
                                generation_config=generation_config,
                                safety_settings=safety_settings)



# Prompt oluşturma
prompt_parts = [
    f"""Bu googleda oteller için yazılmıştüm türkçe müşteri yorumlarını çıkar. sadece ve sadece senden
    istediğim görevi yapmanı istiyorum.Emin olmadığın verileri yazma.not ekleme. Başka başlık ekleme.Tüm yorumları getir. Alt başlık ekleme.
      Puanı düşük yorumları kazı. Yapılmış puanı düşük yorumları ve puanlarını getir.Benzersiz yorumları kazı.Olumsuz veya düşük puanlı yorumları getirmen
      çok önemli bunnları sadece getirmeni istiyorum
      Yalnızca örnek olarak verdiğim şu formatı kullan ve tüm başlıkları doldur Yapılan Tüm yorumları [Yorumların tamamı] veriyi kazı ve her
      müşteri yorumunun puanını karşısında gösteren dataframe şeklinde göster.
      :   <b>[Otel İsmi]</b><br> [Otel ile ilgili Müşteri Yorumları]<br><br><b>Müşteri Puanı:</b>[Yalnızca Müşteri Yorum Puanı
    Puan] * (bilgi)<br>
    """,]

response = model.generate_content(prompt_parts)
print(response.text)
