# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/oflazer/Mert/Sikayetvar_operator/sikayetvar_comments_labeled.csv")

# %%
data.iloc[5,0]
# Out:
# '22.03.2024 tarihinde 5316***550 numaralı hattın fatura ödemesini yapmak isterken mobil bankacılık üzerinden sehven 5376***550 numaralı hattın fatura borcunu ödedim. İlgili operatör şirketi olan Vodafone ile iletişime geçtim ve iade için istedikleri belgeleri mail üzerinden ulaştırdım. Vodafone Genel...'
