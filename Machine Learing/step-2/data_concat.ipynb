# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Birinci CSV dosyasını oku
df1 = pd.read_csv('/content/drive/MyDrive/oflazer/data/yeniVeriler/comments-irem.csv')
df1 = df1.rename(columns={'comments': 'Comment'})

# İkinci CSV dosyasını oku
df2 = pd.read_csv('/content/drive/MyDrive/oflazer/data/yeniVeriler/googleplay10000.csv')

#df3 = pd.read_csv('/content/drive/MyDrive/oflazer/data/sikayetvar_comments_turkcell_page1_to_350.csv')

#df4 = pd.read_csv('/content/drive/MyDrive/oflazer/data/sikayetvar_comments_vodafone_page1_to_350.csv')

# DataFrame'leri birleştirme
birlesmis_df = pd.concat([df1, df2], ignore_index=True)

# %%
birlesmis_df
# Out:
#         id                                            Comment  label
# 0      1.0  Tam kalıbınızı alabilirsiniz..biraz salaş bir ...    NaN
# 1      2.0                                      iç gösteriyor    NaN
# 2      3.0  dilediğiniz gibi gönül ferahlığıyla alışveriş ...    NaN
# 3      4.0  Hızlı bir teslimat oldu özenle katlanıp temiz ...    NaN
# 4      5.0  Ürün çok güzel bir beden küçük alınabilir soru...    NaN
# ...    ...                                                ...    ...
# 23210  NaN  Merhaba uygulamanız güzel, ancak çok eksik var...    NaN
# 23211  NaN  Nasdaq halka arzlari da eklenebilir çok güzel ...    NaN
# 23212  NaN  Uygulama gerçekten çok güzel özellikle al tut ...    NaN
# 23213  NaN           Kripto yatırımları gelse çok iyi olur...    NaN
# 23214  NaN  Bir yıldız verenler genellikle uygulamanın eks...    NaN
#
# [23215 rows x 3 columns]

# %%
birlesmis_df = birlesmis_df['Comment']

# %%
birlesmis_df
# Out:
# 0        Tam kalıbınızı alabilirsiniz..biraz salaş bir ...
# 1                                            iç gösteriyor
# 2        dilediğiniz gibi gönül ferahlığıyla alışveriş ...
# 3        Hızlı bir teslimat oldu özenle katlanıp temiz ...
# 4        Ürün çok güzel bir beden küçük alınabilir soru...
#                                ...
# 23210    Merhaba uygulamanız güzel, ancak çok eksik var...
# 23211    Nasdaq halka arzlari da eklenebilir çok güzel ...
# 23212    Uygulama gerçekten çok güzel özellikle al tut ...
# 23213             Kripto yatırımları gelse çok iyi olur...
# 23214    Bir yıldız verenler genellikle uygulamanın eks...
# Name: Comment, Length: 23215, dtype: object

# %%
birlesmis_df.to_csv('/content/drive/MyDrive/oflazer/data/yeniVeriler/datall2.csv', index=False, encoding='utf-8')
