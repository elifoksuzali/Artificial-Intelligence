# %%
import time
print(time.ctime())
# Out:
# Sat Nov  4 18:16:08 2023

# %%
time.sleep(5)
print (time.ctime())
# Out:
# Sat Nov  4 18:22:47 2023

# %% [markdown]
# This is **bold**.
# This is *italic*.
# This is ~strikethrough~.

# %% [markdown]
# $\sqrt{3x-1}+(1+x)^2$

# %%
import numpy as np
from matplotlib import pyplot as plt
y = np.random.randn(100)
x = [x for x in range(len(y))]
plt.plot(x, y, '-')
plt.fill_between(x, y, 200, where=(y > 195), facecolor='g', alpha=0.6)
plt.title("Sample Plot")
plt.show()

# %%
# %%html
# <marquee style='width: 50%; color: Green;'><b>Büyük Veri Analizi!</b></marquee>
# Out:
# <marquee style='width: 50%; color: Green;'><b>Büyük Veri Analizi!</b></marquee>

# %%
# @title Form
giris = 10 # @param {type:"integer"}

# %%
import time
print(time.ctime())
time.sleep(giris)
print (time.ctime())
# Out:
# Sat Nov  4 20:58:28 2023
# Sat Nov  4 20:58:38 2023

# %%
color = 'red' #@param ["red", "green", "blue"]
print(color)
# Out:
# red

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 3972392414003412464
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14357954560
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 1601970853464625541
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13294208 kB
# MemFree:         8476904 kB
# MemAvailable:   11228240 kB
# Buffers:           67264 kB
# Cached:          2895624 kB
# SwapCached:            0 kB
# Active:           734964 kB
# Inactive:        3682920 kB
# Active(anon):       1052 kB
# Inactive(anon):  1465480 kB
# Active(file):     733912 kB
# Inactive(file):  2217440 kB
# Unevictable:           4 kB
# Mlocked:               4 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               132 kB
# Writeback:             0 kB
# AnonPages:       1454952 kB
# Mapped:           827156 kB
# Shmem:             11532 kB
# KReclaimable:      81880 kB
# Slab:             126636 kB
# SReclaimable:      81880 kB
# SUnreclaim:        44756 kB
# KernelStack:        4812 kB
# PageTables:        16768 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6647104 kB
# Committed_AS:    3246224 kB
# VmallocTotal:   34359738367 kB
# ...

# %%
# Java'nın yüklenmesi
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# Spark'ın indirilmesi ve kurulumu
# !wget -q https://downloads.apache.org/spark/spark-3.5.0/spark-3.5.0-bin-hadoop3.tgz
# !tar xf spark-3.5.0-bin-hadoop3.tgz
# !pip install -q findspark

# Ortam değişkenlerinin ayarlanması
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.5.0-bin-hadoop3"

# Spark'ın başlatılması
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://5610796a6fb4:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# Check the pyspark version
import pyspark
print(pyspark.__version__)
# Out:
# 3.5.0

# %%
# !pip install pyspark py4j
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.0-py2.py3-none-any.whl size=317425344 sha256=ffb4af7b4ddbe83b2c9d9403269e14c6af9222bf44118f9ff48deb6f719d59c7
#   Stored in directory: /root/.cache/pip/wheels/41/4e/10/c2cf2467f71c678cfc8a6b9ac9241e5e44a01940da8fbb17fc
# Successfully built pyspark
# ...

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.master("local[*]").getOrCreate()
